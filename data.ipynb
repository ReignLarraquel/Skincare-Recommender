# %%
import pandas as pd

def convert_to_list(string):
    return string.split(', ')

df = pd.read_csv('cosmetics.csv')
df['Ingredients'] = df['Ingredients'].apply(convert_to_list)

# %%
df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
fd = df[df.Combination == 0]

# %%
fd
# Out:
#             Label                          Brand  \
# 9     Moisturizer                         LA MER
# 10    Moisturizer                          FRESH
# 18    Moisturizer                          FRESH
# 19    Moisturizer                          SK-II
# 21    Moisturizer                   BAREMINERALS
# ...           ...                            ...
# 1465  Sun protect                    URBAN DECAY
# 1466  Sun protect                KATE SOMERVILLE
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
#
#                                                    Name  Price  Rank  \
# 9     Little Miss Miracle Limited-Edition Crème de l...    325   5.0
# 10                     Lotus Youth Preserve Moisturizer     45   4.3
# 18                      Rose Deep Hydration Moisturizer     40   4.4
# 19                              R.N.A. POWER Face Cream    230   4.3
# ...

# %%
display(df.iloc[1])
# Out:
# Label                                                Moisturizer
# Brand                                                      SK-II
# Name                                    Facial Treatment Essence
# Price                                                        179
# Rank                                                         4.1
# Ingredients    [Galactomyces Ferment Filtrate (Pitera), Butyl...
# Combination                                                    1
# Dry                                                            1
# Normal                                                         1
# Oily                                                           1
# Sensitive                                                      1
# Name: 1, dtype: object

# %%
df
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
df[df.Ingredients != "Water"]
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
i = 0

words = []

words = df.Ingredients[0]

words[0]
# Out:
# 'Algae (Seaweed) Extract'

# %%
def allergenFilter (xdd, allergen):
    row = 0
    list = []
    test = xdd
    
    for row in range (len(xdd)):
        list = xdd.Ingredients[row]
        for i in list:
            if i == allergen:
                test = test.drop(row)
                break
    return test

# %%
xpp = pd.DataFrame()
xpp = allergenFilter(df, "Water")
xpp
# Out:
#             Label               Brand  \
# 7     Moisturizer      DRUNK ELEPHANT
# 11    Moisturizer  KIEHL'S SINCE 1851
# 13    Moisturizer        SUNDAY RILEY
# 17    Moisturizer            CLINIQUE
# 26    Moisturizer      DRUNK ELEPHANT
# ...           ...                 ...
# 1460  Sun protect          SUPERGOOP!
# 1462  Sun protect               COOLA
# 1463  Sun protect       VITA LIBERATA
# 1465  Sun protect         URBAN DECAY
# 1471  Sun protect          DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 7                       Virgin Marula Luxury Facial Oil     72   4.4
# 11                        Midnight Recovery Concentrate     47   4.4
# 13                              Luna Sleeping Night Oil    105   4.1
# 17    Moisture Surge 72-Hour Auto-Replenishing Hydrator     39   4.4
# 26                 Virgin Marula Luxury Facial Oil Mini     40   4.5
# ...                                                 ...    ...   ...
# ...

# %%
def skinType(test_df, x):
    
    match x:
        case "Combination":
            test_df = test_df[test_df.Combination == 1]
        case "Dry":
            test_df = test_df[test_df.Dry == 1]
        case "Normal":
            test_df = test_df[test_df.Normal == 1]
        case "Oily":
            test_df = test_df[test_df.Oily == 1]
        case "Sensitive":
            test_df = test_df[test_df.Sensitive == 1]
            
    return test_df

# %%
ddx = skinType(df, "Dry")

# %%
ddx
# Out:
#             Label           Brand  \
# 0     Moisturizer          LA MER
# 1     Moisturizer           SK-II
# 2     Moisturizer  DRUNK ELEPHANT
# 3     Moisturizer          LA MER
# 4     Moisturizer    IT COSMETICS
# ...           ...             ...
# 1459  Sun protect     MOROCCANOIL
# 1460  Sun protect      SUPERGOOP!
# 1464  Sun protect    IT COSMETICS
# 1467  Sun protect          KORRES
# 1471  Sun protect      DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
# ...                                                 ...    ...   ...
# ...

# %%
xpx = allergenFilter(df, "Water")

# %%
xpx
# Out:
#             Label               Brand  \
# 7     Moisturizer      DRUNK ELEPHANT
# 11    Moisturizer  KIEHL'S SINCE 1851
# 13    Moisturizer        SUNDAY RILEY
# 17    Moisturizer            CLINIQUE
# 26    Moisturizer      DRUNK ELEPHANT
# ...           ...                 ...
# 1460  Sun protect          SUPERGOOP!
# 1462  Sun protect               COOLA
# 1463  Sun protect       VITA LIBERATA
# 1465  Sun protect         URBAN DECAY
# 1471  Sun protect          DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 7                       Virgin Marula Luxury Facial Oil     72   4.4
# 11                        Midnight Recovery Concentrate     47   4.4
# 13                              Luna Sleeping Night Oil    105   4.1
# 17    Moisture Surge 72-Hour Auto-Replenishing Hydrator     39   4.4
# 26                 Virgin Marula Luxury Facial Oil Mini     40   4.5
# ...                                                 ...    ...   ...
# ...

# %%
xpx = skinType(xpx, "Dry")

# %%
xpx
# Out:
#             Label               Brand  \
# 7     Moisturizer      DRUNK ELEPHANT
# 11    Moisturizer  KIEHL'S SINCE 1851
# 13    Moisturizer        SUNDAY RILEY
# 17    Moisturizer            CLINIQUE
# 26    Moisturizer      DRUNK ELEPHANT
# ...           ...                 ...
# 1456  Sun protect       CANE + AUSTIN
# 1457  Sun protect     MDSOLARSCIENCES
# 1458  Sun protect               COOLA
# 1460  Sun protect          SUPERGOOP!
# 1471  Sun protect          DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 7                       Virgin Marula Luxury Facial Oil     72   4.4
# 11                        Midnight Recovery Concentrate     47   4.4
# 13                              Luna Sleeping Night Oil    105   4.1
# 17    Moisture Surge 72-Hour Auto-Replenishing Hydrator     39   4.4
# 26                 Virgin Marula Luxury Facial Oil Mini     40   4.5
# ...                                                 ...    ...   ...
# ...

# %%
ddx = pd.DataFrame()

# %%
ddx = allergenFilter(df, "Algae (Seaweed) Extract")
ddx
# Out:
#             Label                          Brand  \
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 4     Moisturizer                   IT COSMETICS
# 5     Moisturizer                         TATCHA
# 6     Moisturizer                 DRUNK ELEPHANT
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
# 5                                       The Water Cream     68   4.2
# ...

# %%
ddx = skinType(ddx, "Dry")
ddx
# Out:
#             Label           Brand  \
# 1     Moisturizer           SK-II
# 2     Moisturizer  DRUNK ELEPHANT
# 4     Moisturizer    IT COSMETICS
# 6     Moisturizer  DRUNK ELEPHANT
# 7     Moisturizer  DRUNK ELEPHANT
# ...           ...             ...
# 1459  Sun protect     MOROCCANOIL
# 1460  Sun protect      SUPERGOOP!
# 1464  Sun protect    IT COSMETICS
# 1467  Sun protect          KORRES
# 1471  Sun protect      DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
# 6                             Lala Retro™ Whipped Cream     60   4.2
# 7                       Virgin Marula Luxury Facial Oil     72   4.4
# ...                                                 ...    ...   ...
# ...
